# %%
#3.3 EWO Revision 2 with the Best Combination
#EWO = Elliott Wave Oscillator
#The current code only focuses on the long position

import pandas_datareader as pdr
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import dataframe_image as dfi
import seaborn as sns
from pylab import *

#lobf(x) function returns the slope of the line of best fit using OLS with input of pandas series
def lobf(x):
    line_fitter = LinearRegression()
    line_fitter.fit(np.array(x.index).reshape(-1 , 1), x.values)
    return line_fitter.coef_

# %%
target_market = 'SPY'
start_date = '2010-06-28'
end_date = '2019-06-28'

#Import and initialize SPY dataframe
sp500 = pdr.get_data_yahoo(target_market, start_date, end_date)
day = np.arange(1, len(sp500) + 1)
sp500['Day'] = day 
sp500['2-day'] = sp500['Close'].rolling(2).mean()   #Column for 2-day SMA
sp500['45-day'] = sp500['Close'].rolling(45).mean() #Column for 45-day SMA
sp500['50-day'] = sp500['Close'].rolling(50).mean() #Column for 50-day SMA
sp500['EWO'] = sp500['2-day'] - sp500['45-day']     #Column for EWO
sp500 = sp500[['Day', 'Open', 'Close', '2-day', '45-day', '50-day', 'EWO']]
sp500 = sp500.reset_index()
sp500 = sp500.set_index('Day')

#Check whether EWO of each day is over a certain positive value, which is 1% of 2-day SMA
#(value 1 = Yes, value 0 = No)
sp500['Filter1'] = np.where(sp500['EWO'] > sp500['2-day']/100, 1, 0)

#Check whether the slope of the line of best fit corresponding to five most recent EWO values is positive
#(value 1 = Yes, value 0 = No)
sp500['Filter2'] = np.where(sp500['EWO'].rolling(5).apply(lobf) > 0, 1, 0)

#Check whether the current price is in uptrend (i.e. Closing Price > 50-day SMA)
#(value 1 = Yes, value 0 = No)
sp500['Filter3'] = np.where(sp500['Close'] > sp500['50-day'], 1, 0)

sp500.dropna(inplace=True)

#Indicate where the 5-day EWO's slope is negative AND where the price is in downtrend
#(value -1 = Yes, value 0 = No)
sp500['Exit1'] = np.where(sp500['EWO'].rolling(5).apply(lobf) < 0, -1, 0)
sp500['Exit2'] = np.where(sp500['Close'].rolling(125).apply(lobf) < 0, -1, 0)

#sp500_buy dataframe refers to the buy signals, where all the filters are satistfied
condition1 = (sp500['Filter1'] == 1)
condition2 = (sp500['Filter2'] == 1)
condition3 = (sp500['Filter3'] == 1)
sp500_buy = sp500.loc[condition1&condition2&condition3]

# %%
#Backtesting of initial strategy on SPY from start_date to end_date
budget = 100000 #Initial Budget = 100,000 USD
buy_list = []   #List storing all the buy signals
sell_list = []  #List storing all the sell signals
sold_day = 0
bought_amount = 0
trade_num = 0

for i in range(len(list(sp500_buy.index))-1): #Iterate the elements in sp500_buy, which contains buy signals
    #If there are consecutive buy signals w/o a sell signal, continue the first buy signal
    if sold_day > list(sp500_buy.index)[i]+1: 
        continue
    if bought_amount == 0: #Enter a trade only when there is no current position
        #Buy the security at the next morning's open price
        bought_day = list(sp500_buy.index)[i]+1
        buy_list.append(bought_day)
        bought_price = sp500.loc[bought_day, 'Open']
        bought_amount = budget // bought_price #Buy as many security as the budget allows at that price
        budget -= bought_amount * bought_price #Remaining budget after entering a long position
        print(int(bought_amount), "amount of SPY security is bought at",
             bought_price, "on", sp500.loc[bought_day, "Date"], "(Day", bought_day, ")")
        print(budget, "is the remaining budget")
    
    #Beginning from the day of long position until the end_date,
    #check whether both exit signals are satisfied simultaneously or whether it is the last day of trading
    for j in range(bought_day, sp500.iloc[[-1]].index[0]):
        if (sp500.loc[j, 'Exit1'] == -1) and (sp500.loc[j, 'Exit2'] == -1) or (j == sp500.iloc[[-1]].index[0]-1):
            #Sell the security at the next morning's open price
            sold_price = sp500.loc[j+1, 'Open']
            sold_day = j+1
            sell_list.append(sold_day)
            budget += bought_amount * sold_price
            print(int(bought_amount), "amount of SPY security is sold at",
                  sold_price, 'on', sp500.loc[sold_day, "Date"], "(Day", sold_day, ")")
            print("After closing the position, current budget is", budget)
            print("\n")
            bought_amount = 0 #Reset the parameter
            trade_num += 1
            break

print("The final budget of EWO strategy is", round(budget), "USD")
print("Total number of trades is", trade_num)

#All buy signals after the trade
sp500_buy = sp500.copy()
sp500_buy = sp500_buy.loc[buy_list] 

#All sell signals after the trade
sp500_sell = sp500.copy()
sp500_sell = sp500_sell.loc[sell_list]
# Out:
# 910 amount of SPY security is bought at 109.86000061035156 on 2010-09-08 00:00:00 (Day 51 )
# 27.399444580078125 is the remaining budget
# 910 amount of SPY security is sold at 130.60000610351562 on 2011-07-28 00:00:00 (Day 275 )
# After closing the position, current budget is 118873.4049987793
#
#
# 985 amount of SPY security is bought at 120.5999984741211 on 2011-10-12 00:00:00 (Day 328 )
# 82.40650177001953 is the remaining budget
# 985 amount of SPY security is sold at 123.08999633789062 on 2011-10-21 00:00:00 (Day 335 )
# After closing the position, current budget is 121326.05289459229
#
#
# 977 amount of SPY security is bought at 124.16999816894531 on 2011-10-24 00:00:00 (Day 336 )
# 11.964683532714844 is the remaining budget
# 977 amount of SPY security is sold at 123.83000183105469 on 2011-11-02 00:00:00 (Day 343 )
# After closing the position, current budget is 120993.87647247314
#
#
# 953 amount of SPY security is bought at 126.91999816894531 on 2011-11-08 00:00:00 (Day 347 )
# 39.11821746826172 is the remaining budget
# 953 amount of SPY security is sold at 125.83000183105469 on 2011-11-11 00:00:00 (Day 350 )
# After closing the position, current budget is 119955.10996246338
#
#
# 961 amount of SPY security is bought at 124.80999755859375 on 2011-11-16 00:00:00 (Day 353 )
# 12.702308654785156 is the remaining budget
# 961 amount of SPY security is sold at 122.5 on 2011-11-18 00:00:00 (Day 355 )
# After closing the position, current budget is 117735.20230865479
#
#
# 933 amount of SPY security is bought at 126.12000274658203 on 2011-12-02 00:00:00 (Day 364 )
# 65.23974609375 is the remaining budget
# 933 amount of SPY security is sold at 124.51000213623047 on 2011-12-09 00:00:00 (Day 369 )
# After closing the position, current budget is 116233.07173919678
#
#
# 921 amount of SPY security is bought at 126.16999816894531 on 2011-12-27 00:00:00 (Day 380 )
# 30.50342559814453 is the remaining budget
# 921 amount of SPY security is sold at 127.76000213623047 on 2012-01-03 00:00:00 (Day 384 )
# After closing the position, current budget is 117697.4653930664
#
#
# 925 amount of SPY security is bought at 127.19999694824219 on 2012-01-04 00:00:00 (Day 385 )
# 37.46821594238281 is the remaining budget
# 925 amount of SPY security is sold at 136.00999450683594 on 2012-07-10 00:00:00 (Day 514 )
# After closing the position, current budget is 125846.71313476562
#
#
# 925 amount of SPY security is bought at 135.97000122070312 on 2012-07-17 00:00:00 (Day 519 )
# 74.46200561523438 is the remaining budget
# 925 amount of SPY security is sold at 135.19000244140625 on 2012-07-24 00:00:00 (Day 524 )
# After closing the position, current budget is 125125.21426391602
#
#
# 903 amount of SPY security is bought at 138.52000427246094 on 2012-07-30 00:00:00 (Day 528 )
# 41.65040588378906 is the remaining budget
# 903 amount of SPY security is sold at 138.55999755859375 on 2012-08-03 00:00:00 (Day 532 )
# After closing the position, current budget is 125161.32820129395
#
#
# 892 amount of SPY security is bought at 140.17999267578125 on 2012-08-07 00:00:00 (Day 534 )
# 120.77473449707031 is the remaining budget
# 892 amount of SPY security is sold at 141.2899932861328 on 2012-08-14 00:00:00 (Day 539 )
# After closing the position, current budget is 126151.44874572754
#
#
# 888 amount of SPY security is bought at 141.97999572753906 on 2012-08-20 00:00:00 (Day 543 )
# 73.21253967285156 is the remaining budget
# 888 amount of SPY security is sold at 141.47000122070312 on 2012-08-23 00:00:00 (Day 546 )
# After closing the position, current budget is 125698.57362365723
#
#
# 872 amount of SPY security is bought at 144.00999450683594 on 2012-09-07 00:00:00 (Day 556 )
# 121.85841369628906 is the remaining budget
# 872 amount of SPY security is sold at 195.42999267578125 on 2015-08-25 00:00:00 (Day 1300 )
# After closing the position, current budget is 170536.81202697754
#
#
# 846 amount of SPY security is bought at 201.4199981689453 on 2015-10-12 00:00:00 (Day 1333 )
# 135.4935760498047 is the remaining budget
# 846 amount of SPY security is sold at 202.8300018310547 on 2015-10-16 00:00:00 (Day 1337 )
# After closing the position, current budget is 171729.67512512207
#
#
# 848 amount of SPY security is bought at 202.5 on 2015-10-19 00:00:00 (Day 1338 )
# 9.675125122070312 is the remaining budget
# 848 amount of SPY security is sold at 209.30999755859375 on 2015-11-09 00:00:00 (Day 1353 )
# After closing the position, current budget is 177504.55305480957
#
#
# 850 amount of SPY security is bought at 208.58999633789062 on 2015-11-19 00:00:00 (Day 1361 )
# 203.05616760253906 is the remaining budget
# 850 amount of SPY security is sold at 209.42999267578125 on 2015-11-27 00:00:00 (Day 1366 )
# After closing the position, current budget is 178218.5499420166
#
#
# 913 amount of SPY security is bought at 195.11000061035156 on 2016-02-29 00:00:00 (Day 1428 )
# 83.119384765625 is the remaining budget
# 913 amount of SPY security is sold at 199.9600067138672 on 2016-03-10 00:00:00 (Day 1436 )
# After closing the position, current budget is 182646.60551452637
#
#
# 903 amount of SPY security is bought at 202.16000366210938 on 2016-03-14 00:00:00 (Day 1438 )
# 96.12220764160156 is the remaining budget
# 903 amount of SPY security is sold at 202.0 on 2016-03-24 00:00:00 (Day 1446 )
# After closing the position, current budget is 182502.1222076416
#
#
# 886 amount of SPY security is bought at 205.91000366210938 on 2016-03-31 00:00:00 (Day 1450 )
# 65.85896301269531 is the remaining budget
# 886 amount of SPY security is sold at 204.19000244140625 on 2016-04-06 00:00:00 (Day 1454 )
# After closing the position, current budget is 180978.20112609863
#
#
# 869 amount of SPY security is bought at 208.07000732421875 on 2016-04-14 00:00:00 (Day 1460 )
# 165.36476135253906 is the remaining budget
# 869 amount of SPY security is sold at 208.5500030517578 on 2016-04-22 00:00:00 (Day 1466 )
# After closing the position, current budget is 181395.31741333008
#
#
# 866 amount of SPY security is bought at 209.44000244140625 on 2016-05-26 00:00:00 (Day 1490 )
# 20.275299072265625 is the remaining budget
# 866 amount of SPY security is sold at 270.30999755859375 on 2018-05-29 00:00:00 (Day 1994 )
# After closing the position, current budget is 234108.73318481445
#
#
# 851 amount of SPY security is bought at 275.04998779296875 on 2018-06-05 00:00:00 (Day 1999 )
# 41.193572998046875 is the remaining budget
# 851 amount of SPY security is sold at 279.010009765625 on 2018-06-14 00:00:00 (Day 2006 )
# After closing the position, current budget is 237478.71188354492
#
#
# 852 amount of SPY security is bought at 278.4100036621094 on 2018-07-10 00:00:00 (Day 2023 )
# 273.3887634277344 is the remaining budget
# 852 amount of SPY security is sold at 265.7799987792969 on 2018-11-26 00:00:00 (Day 2120 )
# After closing the position, current budget is 226717.94772338867
#
#
# 856 amount of SPY security is bought at 264.82000732421875 on 2019-01-22 00:00:00 (Day 2157 )
# 32.021453857421875 is the remaining budget
# 856 amount of SPY security is sold at 271.20001220703125 on 2019-02-11 00:00:00 (Day 2171 )
# After closing the position, current budget is 232179.23190307617
#
#
# 848 amount of SPY security is bought at 273.7799987792969 on 2019-02-14 00:00:00 (Day 2174 )
# 13.792938232421875 is the remaining budget
# 848 amount of SPY security is sold at 279.1300048828125 on 2019-02-26 00:00:00 (Day 2181 )
# After closing the position, current budget is 236716.03707885742
#
#
# 841 amount of SPY security is bought at 281.3699951171875 on 2019-03-14 00:00:00 (Day 2193 )
# 83.87118530273438 is the remaining budget
# 841 amount of SPY security is sold at 282.1600036621094 on 2019-03-20 00:00:00 (Day 2197 )
# After closing the position, current budget is 237380.43426513672
#
#
# 833 amount of SPY security is bought at 284.70001220703125 on 2019-04-01 00:00:00 (Day 2205 )
# 225.3240966796875 is the remaining budget
# 833 amount of SPY security is sold at 292.5799865722656 on 2019-06-28 00:00:00 (Day 2267 )
# After closing the position, current budget is 243944.45291137695
#
#
# The final budget of EWO strategy is 243944 USD
# Total number of trades is 27

# %%
#Visualize the price trend, EWO value, buy signals, and sell signals throughout the trading
plt.rcParams['figure.figsize'] = 12, 6
 
plt.subplot(211) #Upper plot
plt.grid(True, alpha = .3)
plt.plot(sp500['Date'], sp500['Close'], label = 'SP500')   #SP500
plt.plot(sp500['Date'], sp500['2-day'], label = '2-day')   #2-day SMA
plt.plot(sp500['Date'], sp500['45-day'], label = '45-day') #45-day SMA
plt.plot(sp500['Date'], sp500['50-day'], label = '50-day') #50-day SMA
plt.plot(sp500_buy['Date'], sp500_buy['Close'], '^',
         color = 'brown', label='Buy', markersize = 9) #Buy signals
plt.plot(sp500_sell['Date'], sp500_sell['Open'], '.',
         color = 'k', label='Sell', markersize = 9)    #Sell signals
plt.legend(loc='upper left')

plt.subplot(212) #Lower plot for EWO 
plt.grid(True, alpha = .3)
plt.plot(sp500['Date'], sp500['EWO'], color='blue', label = 'EWO') #EWO
plt.plot(sp500_buy['Date'], sp500_buy['EWO'], '^',
         color = 'brown', label='Buy', markersize = 9) #Buy signals
plt.plot(sp500_sell['Date'], sp500_sell['EWO'], '.',
         color = 'k', label='Sell', markersize = 9)    #Sell signals
plt.axhline(0, color='lightgray', linestyle='--', linewidth=2) #x-axis
plt.legend(loc='lower left')
